# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
# %matplotlib inline

# %%
red_df = pd.read_csv('./winequality-red.csv', sep=';')
red_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
white_df = pd.read_csv('./winequality-white.csv', sep=';')
white_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
print("# of red sample is %.f and # of white ones is %.f" %(red_df.shape[0], white_df.shape[0]))
# Out:
# # of red sample is 1599 and # of white ones is 4898

# %%
print("# of columns are %.f " %(red_df.shape[1]))
# Out:
# #of columns are 12

# %%
red_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
white_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed acidity           4898 non-null float64
# volatile acidity        4898 non-null float64
# citric acid             4898 non-null float64
# residual sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free sulfur dioxide     4898 non-null float64
# total sulfur dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
sum(red_df.duplicated())
# Out:
# 240

# %%
sum(white_df.duplicated())
# Out:
# 937

# %%
white_df.index[white_df.duplicated()]
# Out:
# Int64Index([   4,    5,    7,    8,   20,   39,   48,   61,   63,   74,
#             ...
#             4796, 4801, 4819, 4820, 4826, 4828, 4850, 4851, 4856, 4880],
#            dtype='int64', length=937)

# %%
red_df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
white_df.quality.unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9])

# %%
red_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# **In order to combint red and white dataframes, we first asigne color to each data frame**

# %%
np.array(['RED']).repeat(11)
# Out:
# array(['RED', 'RED', 'RED', 'RED', 'RED', 'RED', 'RED', 'RED', 'RED',
#        'RED', 'RED'], dtype='<U3')

# %%
red_df['color'] = np.array(['red']).repeat(red_df.shape[0])
white_df['color'] = np.array(['white']).repeat(white_df.shape[0])
#white_df.drop(['white'],axis=1, inplace=True)

red_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
combined_df = red_df.append(white_df, ignore_index=True)
combined_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %% [markdown]
# ## **Here we are exploring data with visualisation**

# %%
i=0
plt.figure(figsize=(20,10))
for col in combined_df.columns.values:
    if combined_df[col].dtype != object:
        plt.subplot(3,4,i+1)
        combined_df[col].plot(kind='hist')
        plt.xlabel(col, fontsize=16)
        i+=1

# %%
combined_df.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality', 'color'], dtype=object)

# %%
sns.pairplot(combined_df[['volatile acidity',
       'residual sugar','pH', 'alcohol',
       'quality']])

# %%
combined_df.groupby(['quality', 'color'], as_index=False)['pH'].mean()
# Out:
#     quality  color        pH
# 0         3    red  3.398000
# 1         3  white  3.187500
# 2         4    red  3.381509
# 3         4  white  3.182883
# 4         5    red  3.304949
# 5         5  white  3.168833
# 6         6    red  3.318072
# 7         6  white  3.188599
# 8         7    red  3.290754
# 9         7  white  3.213898
# 10        8    red  3.267222
# 11        8  white  3.218686
# 12        9  white  3.308000

# %%
combined_df.groupby(['color'], as_index=False)['quality'].mean()
# Out:
#    color   quality
# 0    red  5.636023
# 1  white  5.877909

# %% [markdown]
# ## What level of acidity (pH value) receives the highest average rating?
#
# This question is more tricky because unlike color, which has clear categories you can group by (red and white) pH is a quantitative variable without clear categories. However, there is a simple fix to this. You can create a categorical variable from a quantitative variable by creating your own categories. pandas' cut function let's you "cut" data in groups. Using this, create a new column called acidity_levels with these categories:
#
# Acidity Levels:
# High: Lowest 25% of pH values
# Moderately High: 25% - 50% of pH values
# Medium: 50% - 75% of pH values
# Low: 75% - max pH value

# %%
combined_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
bins = pd.IntervalIndex.from_tuples([(2.720000, 3.110000), (3.110000, 3.210000), (3.210000, 3.320000), (3.320000, 4.010000)])
pd.cut(combined_df.pH, bins, labels=['High' ,'Moderately', 'Medium', 'Low'])
# Out:
# 0       (3.32, 4.01]
# 1       (3.11, 3.21]
# 2       (3.21, 3.32]
# 3       (3.11, 3.21]
# 4       (3.32, 4.01]
#             ...
# 6492    (3.21, 3.32]
# 6493    (3.11, 3.21]
# 6494    (2.72, 3.11]
# 6495    (3.32, 4.01]
# 6496    (3.21, 3.32]
# Name: pH, Length: 6497, dtype: category
# Categories (4, interval[float64]): [(2.72, 3.11] < (3.11, 3.21] < (3.21, 3.32] < (3.32, 4.01]]

# %%
x = pd.cut(combined_df['pH'].to_list(), bins)
x.categories = ['High' ,'Moderately', 'Medium', 'Low']
combined_df['acidity_levels'] = x
combined_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color acidity_levels
# 0      9.4        5   red            Low
# ...

# %%
combined_df.groupby('acidity_levels', as_index=False)['quality'].mean()
# Out:
#   acidity_levels   quality
# 0           High  5.783343
# 1     Moderately  5.784540
# 2         Medium  5.850832
# 3            Low  5.859593
